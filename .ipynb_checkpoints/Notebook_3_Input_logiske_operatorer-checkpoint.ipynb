# %% [markdown]
# # Notebook 3: input()-funksjonen og logiske operatorer
#
# **Fag:** Konseptutvikling og programmering
# **Linje:** Informasjonsteknologi og medieproduksjon, Vg1
#
# ## Læringsmål
# Etter denne notebooken skal du kunne:
# - Bruke `input()` til å hente informasjon fra brukeren
# - Forstå hvorfor `input()` alltid gir tekst (streng), og hvordan man gjør om datatypen
# - Bruke sammenlikningsoperatorer (`==`, `!=`, `<`, `>`, `<=`, `>=`)
# - Skrive `if`, `elif` og `else`-setninger
# - Bruke de logiske operatorene `and`, `or` og `not`
#
# ---
# Husk: Kjør cellene med **Shift + Enter**.

# %% [markdown]
# ## 3.1 input()-funksjonen
#
# Så langt har vi selv skrevet inn verdiene i koden. Men ofte ønsker vi at *brukeren* av programmet skal kunne skrive inn informasjon selv, mens programmet kjører. Da bruker vi `input()`.
#
# ```python
# navn = input("Hva heter du? ")
# ```
#
# Når denne linjen kjører, vil Python skrive ut `Hva heter du?` og vente på at brukeren skriver noe og trykker Enter. Det brukeren skriver blir lagret i variabelen `navn`.
#
# **Viktig:** `input()` gir alltid en **tekststreng** tilbake, selv om brukeren skriver inn et tall!

# %%
navn = input("Hva heter du? ")
print("Hei,", navn, "! Hyggelig å møte deg.")
# Out:
# Hva heter du?  Vasyl
# Hei, Vasyl ! Hyggelig å møte deg.

# %% [markdown]
# ### 3.1.1 Endring av datatype fra input
#
# Fordi `input()` alltid gir tekst, får vi problemer hvis vi prøver å regne med det brukeren har skrevet inn direkte.

# %%
alder = input("Hvor gammel er du? ")
print(type(alder))          # Denne er 'str', selv om brukeren skrev et tall!

# Dette vil gi en feilmelding fordi vi prøver å legge sammen tekst og tall:
# neste_ar = alder + 1
# Out:
# Hvor gammel er du?  s
# <class 'str'>

# %% [markdown]
# For å kunne regne med verdien, må vi gjøre den om til et tall med `int()` eller `float()`.

# %%
alder = input("Hvor gammel er du? ")
alder = int(alder)          # Gjør om til heltall
neste_ar = alder + 1
print("Neste år blir du", neste_ar, "år.")
# Out:
# Hvor gammel er du?  16
# Neste år blir du 17 år.

# %% [markdown]
# ### 🔧 Oppgave 3.1.1
# Lag et program som spør brukeren om et tall (bruk `input()`), gjør det om til et flyttall, og skriver ut det dobbelte av tallet.

# %%
# Skriv koden din her
free_robux = input("skriv dine bank kart nummer")
free_robux = int(free_robux)
print(free_robux, "er det riktig nummer? Hvis ja, vent 72 timer før robux kommer!")
# Out:
# skriv dine bank kart nummer 123412312
# 123412312 er det riktig nummer? Hvis ja, vent 72 timer før robux kommer!

# %% [markdown]
# ### 🔧 Oppgave 3.1.2
# Lag et program som spør om navnet og alderen til brukeren (to separate `input()`-kall), og skriver ut en setning som: `Kari er 16 år gammel.`

# %%
# Skriv koden din her
navn = input("hva heter du?")
alder = input("hvor gammel er du?")
alder = int(alder)
print(navn, "er", alder, "år gammel")
# Out:
# hva heter du? vasyl
# hvor gammel er du? 67
# vasyl er 67 år gammel

# %% [markdown]
# ## 3.2 Sammenlikningsoperatorer
#
# Når vi programmerer ønsker vi ofte å sammenlikne to verdier. Resultatet av en sammenlikning er alltid en **boolsk verdi**: `True` eller `False`.
#
# | Operator | Betydning |
# |---|---|
# | `==` | er lik |
# | `!=` | er ikke lik |
# | `<` | mindre enn |
# | `>` | større enn |
# | `<=` | mindre enn eller lik |
# | `>=` | større enn eller lik |
#
# **NB:** `=` brukes til å *tilordne* en verdi til en variabel, mens `==` brukes til å *sammenlikne*. Dette er en av de vanligste nybegynnerfeilene!

# %%
print(5 == 5)     # True
print(5 == 4)     # False
print(5 != 4)     # True
print(3 < 8)      # True
print(3 > 8)      # False
print(3 <= 3)     # True
# Out:
# True
# False
# True
# True
# False
# True

# %% [markdown]
# ### 🔧 Oppgave 3.2.1
# Skriv kode som sjekker (med `print()`) om følgende påstander er sanne eller usanne:
#
# a) `10` er lik `10.0`
# b) `7` er større enn `20`
# c) `15 % 4` er lik `3`

# %%
# Skriv koden din her
print("a.", 10 == 10.0)
print("b.", 7 > 20)
print("c.", 15 % 4 == 3)
# Out:
# a. True
# b. False
# c. True

# %% [markdown]
# ## 3.3 if, elif og else
#
# Med `if` kan vi få programmet til å utføre kode **bare hvis** en betingelse er sann. Med `else` bestemmer vi hva som skal skje **hvis betingelsen ikke er sann**. Med `elif` (else if) kan vi sjekke flere betingelser etter hverandre.
#
# ```python
# if betingelse:
#     # kode som kjøres hvis betingelsen er True
# elif annen_betingelse:
#     # kode som kjøres hvis betingelse 1 er False, men denne er True
# else:
#     # kode som kjøres hvis ingen av betingelsene er True
# ```
#
# **Viktig:** Legg merke til kolon (`:`) etter betingelsen, og at koden under er rykket inn (indentert). Python bruker innrykk for å vite hva som hører til `if`-blokken.

# %%
alder = 17

if alder >= 18:
    print("Du er myndig.")
else:
    print("Du er ikke myndig ennå.")
# Out:
# Du er ikke myndig ennå.

# %%
karakter = 4

if karakter >= 5:
    print("Karakteren er høy")
elif karakter >= 3:
    print("Karakteren er middels")
else:
    print("Karakteren er lav")
# Out:
# Karakteren er middels

# %% [markdown]
# ### 🔧 Oppgave 3.3.1
# Lag et program som ber brukeren skrive inn et tall (`input()`), og skriver ut om tallet er positivt, negativt eller null.

# %%
# Skriv koden din her
tall = input("skriv en tall")
tall = int(tall)

if tall > 0:
    print(tall, "er positiv tall")
elif tall < 0:
    print(tall, "er negativt tall")
else:
    print(tall, "det er bare en null")
# Out:
# skriv en tall 0
# 0 det er bare en null

# %% [markdown]
# ### 🔧 Oppgave 3.3.2
# En nettbutikk gir gratis frakt hvis handlekurven er over 500 kr. Lag et program der brukeren skriver inn totalsummen på handlekurven sin, og programmet skriver ut om handelen får gratis frakt eller ikke.

# %%
# Skriv koden din her

totalsummen = input("skriv inn totalsummen:")
totalsummen = float(totalsummen)
frakt = totalsummen * 0.15

if totalsummen > 500:
    print(totalsummen, "Totalsummen er over 500kr, da er frakt gratis for deg!")
else:
    print(totalsummen + frakt, "er din totalsummen + 15% frakt, fordi totalsummen er mindre enn 500kr. cry about it")
# Out:
# skriv inn totalsummen: 123.34
# 141.841 er din totalsummen + 15% frakt, fordi totalsummen er mindre enn 500kr. cry about it

# %% [markdown]
# ## 3.4 Logiske operatorer: and, or og not
#
# Noen ganger må vi sjekke **flere betingelser samtidig**. Da bruker vi de logiske operatorene:
#
# | Operator | Betydning |
# |---|---|
# | `and` | Begge betingelsene må være sanne |
# | `or` | Minst én av betingelsene må være sann |
# | `not` | Snur om på en boolsk verdi (`True` blir `False` og omvendt) |

# %%
alder = 20
har_lappen = True

if alder >= 18 and har_lappen:
    print("Du kan kjøre bil.")
else:
    print("Du kan ikke kjøre bil.")
# Out:
# Du kan kjøre bil.

# %%
dag = "lørdag"

if dag == "lørdag" or dag == "søndag":
    print("Det er helg!")
else:
    print("Det er hverdag.")
# Out:
# Det er helg!

# %%
er_pausert = False
print(not er_pausert)   # True, fordi vi snur om på verdien
# Out:
# True

# %% [markdown]
# ### 🔧 Oppgave 3.4.1
# Lag et program der du definerer `brukernavn = "admin"` og `passord = "1234"`. Be brukeren skrive inn eget brukernavn og passord med `input()`. Skriv ut `"Innlogging vellykket"` dersom **begge** stemmer, og `"Feil brukernavn eller passord"` ellers.

# %%
# Skriv koden din her
brukernavn = input("enter username")
passord = input ("enter password")

if brukernavn == "admin" and passord == "1234":
    print("Loggin succesfull!")
else:
    print("wrong username or password")
# Out:
# enter username fortnitelover
# enter password abcd
# wrong username or password

# %% [markdown]
# ### 🔧 Oppgave 3.4.2
# Lag et program som sjekker om et tall som brukeren skriver inn er et partall **eller** større enn 100. Skriv ut et passende resultat med `if`/`else`.
#
# *Tips: Bruk `%` for å sjekke om et tall er et partall.*

# %%
# Skriv koden din her
tall = input("skriv ett tall")
tall = int(tall)

if tall >= 100:
    print("tall er større en 100")
elif tall <= 100 and tall % 2 == 0:
    print("tall er et partall, og mindre enn 100")
else:
    print("tall er ikke partall eller 100")
# Out:
# skriv ett tall 25
# tall er ikke partall eller 100

# %% [markdown]
# ---
# ## 3.5 Avsluttende oppgaver
#
# Her finner du flere oppgaver, delt inn i **enkel**, **middels** og **vanskelig**. Jobb deg gjennom i din egen takt - du trenger ikke gjøre alle!

# %% [markdown]
# ### 🟢 Enkelt nivå
#
# **Oppgave A**
# Lag et program som spør brukeren om alderen deres med `input()`, og skriver ut `"Du er myndig"` hvis alderen er 18 eller over, og `"Du er ikke myndig"` ellers.
#
# **Oppgave B**
# Lag et program som spør brukeren om et tall, og skriver ut om tallet er et partall eller et oddetall.

# %%
# Oppgave A
alder = input("skriv hvor gammel er du")
alder = int(alder)

if alder >= 18:
    print("du er myndig")
else:
    print("du er ikke myndig")
# Out:
# skriv hvor gammel er du 3
# du er ikke myndig

# %%
# Oppgave B
tall = input("skriv inn tall")
tall = int(tall)


if tall % 2 == 0:
    print("tall er et partall")
else:
    print("tall er et oddtal")
# Out:
# skriv inn tall 24
# tall er et partall

# %% [markdown]
# ### 🟡 Middels nivå
#
# **Oppgave C**
# Lag et program som ber brukeren skrive inn to tall, og skriver ut hvilket av de to tallene som er størst (bruk `if`/`elif`/`else`).
#
# **Oppgave D**
# Lag et program som spør brukeren om totalsummen på en handlekurv i en nettbutikk. Butikken gir gratis frakt hvis summen er over 500 kr **og** kunden er medlem av kundeklubben. Spør brukeren om begge deler, og skriv ut om de får gratis frakt.

# %%
# Oppgave C
tall_en = input("skriv et tall")
tall_to = input("skriv et andre tall")

if tall_en > tall_to:
    print(tall_en, "er større en", tall_to)
elif tall_en < tall_to:
    print(tall_to, "er større en", tall_en)
else:
    print(tall_en, "er det samme som", tall_to)
# Out:
# skriv et tall 25
# skriv et andre tall 25
# 25 er det samme som 25

# %%
# Oppgave D
totalsummen = input("skriv inn totalsummen:")
totalsummen = float(totalsummen)
medlem = input("er du medlem av våre butikken?(skriv ja eller nei)")
frakt = totalsummen * 0.15

if totalsummen > 500 and medlem == "ja":
    print(totalsummen, "Du betaler uten frakt fordi totalsummen er over 500 og du er medlem med oss!")
else:
    print(totalsummen + frakt, "er din totalsummen fordi den er mindre enn 500 og/eller du er ikke medlem våre. Du må betale frakt xddddddddd")
# Out:
# skriv inn totalsummen: 250
# er du medlem av våre butikken?(skriv ja eller nei) nei
# 287.5 er din totalsummen fordi den er mindre enn 500 og/eller du er ikke medlem våre. Du må betale frakt xddddddddd

# %% [markdown]
# ### 🔴 Vanskelig nivå (utfordrende)
#
# **Oppgave E – Billettsystem**
# Lag et program som spør brukeren om alderen sin, og skriver ut riktig billettype etter disse reglene:
# - Under 6 år: Gratis
# - 6-17 år: Barn/Ungdom
# - 18-29 år: Ung voksen
# - 30-66 år: Voksen
# - 67 år eller eldre: Honnør
#
# *Tips: bruk flere `elif`-betingelser etter hverandre. Vi lager dette som en funksjon i neste notebook!*

# %%
# Oppgave E
alder = input("skriv hvor gammel er du, bare tall")
alder = int(alder)

if alder < 6:
    print("du er under 6 år, biletten er gratis")
elif alder >= 6 and alder <= 17:
    print("Du må betale for barn/ungdom bilett.")
elif alder >= 18 and alder <= 29:
    print("Du må betale for Ung voksen-bilett.")
elif alder >= 30 and alder <= 66:
    print("Du må betale for voksen bilett.")
elif alder >= 66 and alder <= 110:
    print("Du må betale for Honnør bilett.")
else:
    print("hvordna er du ikke dø ennå?")
# Out:
# skriv hvor gammel er du, bare tall 140
# hvordna er du ikke dø ennå?

# %% [markdown]
# ---
# ## Oppsummering
# - `input()` henter tekst fra brukeren – husk å konvertere med `int()`/`float()` om du skal regne
# - Sammenlikningsoperatorer (`== != < > <= >=`) gir `True` eller `False`
# - `if`/`elif`/`else` styrer hvilken kode som kjøres, basert på betingelser
# - `and`, `or` og `not` lar oss kombinere flere betingelser
#
# Neste notebook: **Løkker (for og while)** ➡️
